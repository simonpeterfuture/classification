# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r'C:\Users\AK COMPUTER SOLNZ\Documents\personal development\Data science challenges\Fetal health\fetal_health.csv')

# %%
data.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
data.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
data.shape
# Out:
# (2126, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(), annot= True, cmap='Blues')
plt.show()

# %%
datacorr=data.corr()
x=datacorr["fetal_health"].sort_values(ascending=False)
x
# Out:
# fetal_health                                              1.000000
# prolongued_decelerations                                  0.484859
# abnormal_short_term_variability                           0.471191
# percentage_of_time_with_abnormal_long_term_variability    0.426146
# histogram_variance                                        0.206630
# baseline value                                            0.148151
# severe_decelerations                                      0.131934
# fetal_movement                                            0.088010
# histogram_min                                             0.063175
# light_decelerations                                       0.058870
# histogram_number_of_zeroes                               -0.016682
# histogram_number_of_peaks                                -0.023666
# histogram_max                                            -0.045265
# histogram_width                                          -0.068789
# ...

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=data,palette="Set1")
plt.xticks(rotation=90)
plt.show()

# %%
def removeOutlier(attribute,data):
    lowerbound=attribute.mean() -3*attribute.std()
    upperbound=attribute.mean() +3*attribute.std()
    data1=data[(attribute>lowerbound) & (attribute<upperbound)]
    data=data1.copy()
    return data

# %%
data = removeOutlier(data['histogram_mode'],data)
data = removeOutlier(data['histogram_mean'],data)
data = removeOutlier(data['histogram_median'],data)
data = removeOutlier(data['histogram_variance'],data)
data = removeOutlier(data['percentage_of_time_with_abnormal_long_term_variability'],data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1954 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          1954 non-null   float64
#  1   accelerations                                           1954 non-null   float64
#  2   fetal_movement                                          1954 non-null   float64
#  3   uterine_contractions                                    1954 non-null   float64
#  4   light_decelerations                                     1954 non-null   float64
#  5   severe_decelerations                                    1954 non-null   float64
#  6   prolongued_decelerations                                1954 non-null   float64
#  7   abnormal_short_term_variability                         1954 non-null   float64
# ...

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=data,palette="Set1")
plt.xticks(rotation=90)
plt.show()

# %%
features=data.iloc[0:21]
for i in features.columns:
    plt.figure()
    sns.distplot(x=data[i])
# Out:
# C:\Users\AK COMPUTER SOLNZ\.conda\envs\ztdl\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AK COMPUTER SOLNZ\.conda\envs\ztdl\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
data['fetal_health']=data['fetal_health'].replace({1:0,2:1,3:2})

# %%
data
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
X=data.drop(['fetal_health'], axis=1)
y=data['fetal_health']

# %%
col_names=list(X.columns)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
X_ss=sc.fit_transform(X)
X_ss=pd.DataFrame(X_ss, columns=col_names)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_ss,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model=GradientBoostingClassifier(n_estimators=100,learning_rate=0.3,max_depth=6,random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.3, max_depth=6, random_state=42)

# %%
model.score(X_test,y_test)
# Out:
# 0.9437819420783645

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# 0.9063032367972743
